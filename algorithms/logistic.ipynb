# %% [markdown]
# ### Hyperparameters
#
# #### Models and tasks
#
# <table border="1">
#   <thead>
#     <tr>
#       <th>Model</th>
#       <th>Regression</th>
#       <th>Classification</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Linear Regression</td>
#       <td>Yes</td>
#       <td>No</td>
#     </tr>
#     <tr>
#       <td>Logistic Regression</td>
#       <td>No</td>
#       <td>Yes</td>
#     </tr>
#   </tbody>
# </table>
